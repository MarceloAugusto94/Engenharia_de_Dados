# %%
import pandas as pd
import numpy as np

# %%
dias = pd.date_range(start = '20190101', periods = 12)

dias
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#                '2019-01-09', '2019-01-10', '2019-01-11', '2019-01-12'],
#               dtype='datetime64[ns]', freq='D')

# %%
pessoa = ['George', 'Victor', 'Lucas']

# %%
np.random.choice(pessoa)
# Out:
# 'Victor'

# %%
nome = []
gasto = []

for elemento in range(12):
  nome.append(np.random.choice(pessoa))
  gasto.append(np.round(np.random.rand() * 100, 2))


nome
# Out:
# ['Victor',
#  'Victor',
#  'Lucas',
#  'Victor',
#  'Victor',
#  'George',
#  'Lucas',
#  'George',
#  'George',
#  'Lucas',
#  'Victor',
#  'George']

# %%
gasto
# Out:
# [47.42,
#  66.89,
#  38.54,
#  73.44,
#  39.85,
#  36.87,
#  33.98,
#  57.52,
#  8.14,
#  94.13,
#  1.9,
#  51.85]

# %%
df= pd.DataFrame({'Dia': dias, 'Nome': nome, 'Gasto': gasto})

# %%
df
# Out:
#           Dia    Nome  Gasto
# 0  2019-01-01  Victor  47.42
# 1  2019-01-02  Victor  66.89
# 2  2019-01-03   Lucas  38.54
# 3  2019-01-04  Victor  73.44
# 4  2019-01-05  Victor  39.85
# 5  2019-01-06  George  36.87
# 6  2019-01-07   Lucas  33.98
# 7  2019-01-08  George  57.52
# 8  2019-01-09  George   8.14
# 9  2019-01-10   Lucas  94.13
# 10 2019-01-11  Victor   1.90
# 11 2019-01-12  George  51.85

# %%
df.pivot(index = 'Dia', columns = 'Nome', values = 'Gasto')
# Out:
# Nome        George  Lucas  Victor
# Dia
# 2019-01-01     NaN    NaN   47.42
# 2019-01-02     NaN    NaN   66.89
# 2019-01-03     NaN  38.54     NaN
# 2019-01-04     NaN    NaN   73.44
# 2019-01-05     NaN    NaN   39.85
# 2019-01-06   36.87    NaN     NaN
# 2019-01-07     NaN  33.98     NaN
# 2019-01-08   57.52    NaN     NaN
# 2019-01-09    8.14    NaN     NaN
# 2019-01-10     NaN  94.13     NaN
# 2019-01-11     NaN    NaN    1.90
# 2019-01-12   51.85    NaN     NaN

# %%
# pivot_table - permite valores repetidos no index

# %%
carros = [7, 4, 3, 2, 8]

dias = pd.date_range(start = '20190101', end = '20190101', periods = 5)

vendedor = ['George', 'Vagner', 'Pedro', 'Vagner', 'George']


df = pd.DataFrame({'Vendas': carros, 'Data': dias, 'Vendedor': vendedor})

# %%
df
# Out:
#    Vendas       Data Vendedor
# 0       7 2019-01-01   George
# 1       4 2019-01-01   Vagner
# 2       3 2019-01-01    Pedro
# 3       2 2019-01-01   Vagner
# 4       8 2019-01-01   George

# %%
pd.pivot(df, index = 'Data', columns = 'Vendedor', values = 'Vendas')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-a3df295e8c40> in <module>()
# ----> 1 pd.pivot(df, index = 'Data', columns = 'Vendedor', values = 'Vendas')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/pivot.py in pivot(data, index, columns, values)
#     475         else:
#     476             indexed = data._constructor_sliced(data[values]._values, index=index)
# --> 477     return indexed.unstack(columns)
#     478
#     479
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in unstack(self, level, fill_value)
#    3901         from pandas.core.reshape.reshape import unstack
#    3902
# -> 3903         return unstack(self, level, fill_value)
#    3904
#    3905     # ----------------------------------------------------------------------
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/reshape.py in unstack(obj, level, fill_value)
#     423             return _unstack_extension_series(obj, level, fill_value)
#     424         unstacker = _Unstacker(
# --> 425             obj.index, level=level, constructor=obj._constructor_expanddim,
#     426         )
#     427         return unstacker.get_result(
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/reshape.py in __init__(self, index, level, constructor)
#     118             raise ValueError("Unstacked DataFrame is too big, causing int32 overflow")
#     119
# --> 120         self._make_selectors()
#     121
#     122     @cache_readonly
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/reshape/reshape.py in _make_selectors(self)
#     167
#     168         if mask.sum() < len(self.index):
# --> 169             raise ValueError("Index contains duplicate entries, cannot reshape")
#     170
#     171         self.group_index = comp_index
#
# ValueError: Index contains duplicate entries, cannot reshape

# %%
pd.pivot_table(df, index = 'Data', columns = 'Vendedor', values = 'Vendas')
# Out:
# Vendedor    George  Pedro  Vagner
# Data
# 2019-01-01     7.5    3.0     3.0

# %%
pd.pivot_table(df, index = 'Data', columns = 'Vendedor', values = 'Vendas', aggfunc = 'sum')
# Out:
# Vendedor    George  Pedro  Vagner
# Data
# 2019-01-01      15      3       6
