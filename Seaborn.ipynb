# %% [markdown]
# O Seaborn é uma biblioteca de visualização de dados do Python baseado no Matplotlib. Ele provê uma interface de alto nivel para construção de gráficos estatísticos atrativos e informativos.

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# difinindo tema 
sns.set_theme(style = 'darkgrid')

# %%
# dados
base_dados = sns.load_dataset('tips')

# %%
# visualizando base_dados

base_dados.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# renomeando as colunas

base_dados.rename(columns = {
  'total_bill' : 'Total Conta', 
  'tip' : 'Gorjeta',
  'sex' : 'Sexo', 
  'smoker' : 'Fumante',
  'day' : 'Dia Semana', 
  'time' : 'Período', 
  'size' : 'Pessoas na Mesa'
}, inplace = True)

# %%
base_dados.head()
# Out:
#    Total Conta  Gorjeta    Sexo Fumante Dia Semana Período  Pessoas na Mesa
# 0        16.99     1.01  Female      No        Sun  Dinner                2
# 1        10.34     1.66    Male      No        Sun  Dinner                3
# 2        21.01     3.50    Male      No        Sun  Dinner                3
# 3        23.68     3.31    Male      No        Sun  Dinner                2
# 4        24.59     3.61  Female      No        Sun  Dinner                4

# %% [markdown]
# **Gráfico Relplot**

# %%
sns.relplot(x = 'Total Conta', y = 'Gorjeta', data = base_dados);

# %%
# Passando outro parâmetro como classe no gráfico

sns.relplot(x = 'Total Conta', y = 'Gorjeta', data = base_dados, hue = 'Sexo')

# %%
# Gráfico de linha com 2 eixos

sns.relplot(x = 'Total Conta', y = 'Gorjeta', data = base_dados, kind = 'line')

# %%
sns.relplot(x = 'Total Conta', y = 'Gorjeta', data = base_dados, hue = 'Fumante', kind = 'line')

# %%
sns.histplot(x = 'Total Conta', data = base_dados)

# %%
sns.histplot(x = 'Total Conta', hue = 'Fumante', data = base_dados)

# %%
sns.barplot(x = 'Sexo', y = 'Total Conta', hue = 'Fumante', data = base_dados)

# %%
sns.pairplot(data = base_dados)

# %%
sns.pairplot(hue = 'Sexo', data = base_dados)

# %%
# Menos intuítivo

sns.pairplot(kind = 'kde', data = base_dados)

# %%
sns.boxplot(x = 'Dia Semana', y = 'Total Conta', data = base_dados)

# %%
sns.boxplot(x = 'Dia Semana', y = 'Total Conta', hue = 'Sexo', data = base_dados)
