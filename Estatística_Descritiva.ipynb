# %% [markdown]
# **ESTATÍSTICA DESCRITIVA**
#
# Em sua essência, a Estatística é a ciência que apresenta processos próprios para coletar, apresentar e interpretar adequadamente conjuntos de dados, sejam eles numéricos ou não. Pode-se dizer que seu objetivo é o de apresentar informações sobre dados em análise para que se tenha maior compreensão dos fatos que os mesmos apresentam.
#
# A **estatística descritiva**, como o próprio nome já diz, se preocupa em descrever os dados.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
base_dados = sns.load_dataset('iris')

# %%
base_dados.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
base_dados.shape
# Out:
# (150, 5)

# %% [markdown]
# **MÓDULO 1 - MEDIDAS DE TENDÊNCIA CENTRAL**
#
# As medidas de tendência central são assim denominadas por indicarem um ponto em torno do qual se concentram os dados.

# %% [markdown]
# **MÉDIA ARITMÉTICA**
#
# A média aritmética (X) é a soma de todos os valores observados da variável, dividida pelo número total de observações.

# %%
base_dados['petal_length'].mean()
# Out:
# 3.7580000000000005

# %% [markdown]
# **MODA**
#
# A moda (Mo) é o valor que apresenta a maior frequência da variável entre os valores observados.

# %%
base_dados['petal_length'].mode()
# Out:
# 0    1.4
# 1    1.5
# dtype: float64

# %% [markdown]
# **MEDIANA**
#
# A mediana (Md) é o valor que ocupa a posição central da série de observações de uma variável, em rol, dividindo o conjunto em duas partes iguais, ou seja, a quantidade de valores inferiores à mediana é igua à quantidade de valores superiores a mesma.

# %%
base_dados['petal_length'].median()
# Out:
# 4.35

# %% [markdown]
# **MÓDULO 2 - MEDIDAS SEPARATRIZES**
#
# Estas medidas são valores que ocupam posições no conjunto de dados, em rol, dividindo-o em partes iguais e podem ser:
#
# 1. Quartil: Os quartis dividem o conjunto de dados em quatro partes iguais.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
base_dados['sepal_length'].describe()
# Out:
# count    150.000000
# mean       5.843333
# std        0.828066
# min        4.300000
# 25%        5.100000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: sepal_length, dtype: float64

# %%
sns.boxplot(base_dados['sepal_length'])
